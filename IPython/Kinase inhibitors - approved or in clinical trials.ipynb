# %% [markdown]
# # Kinase inhibitors - approved or in clinical trials
# This notebook extracts all kinase inhibitors that are in clinical trials or on the market.

# %%
import pandas as pd # Import pandas
import pylab
import numpy as np
import matplotlib.pyplot as plt
import rdkit.Chem as Chem
from rdkit.Chem import PandasTools
from rdkit.Chem import Draw
from rdkit.Chem.Draw import IPythonConsole # Enables RDKit IPython integration

# %% [markdown]
# ##### Load the drug data downloaded from [ChEMBL](https://www.ebi.ac.uk/chembl/drugstore)

# %%
dataframe = pd.read_csv('chembl_drugs.txt', delimiter='\t')

# %%
dataframe.columns
# Out:
# Index([u'PARENT_MOLREGNO', u'CHEMBL_ID', u'SYNONYMS', u'DEVELOPMENT_PHASE', u'RESEARCH_CODES', u'APPLICANTS', u'USAN_STEM', u'USAN_STEM_DEFINITION', u'USAN_STEM_SUBSTEM', u'USAN_YEAR', u'FIRST_APPROVAL', u'ATC_CODE', u'ATC_CODE_DESCRIPTION', u'INDICATION_CLASS', u'DRUG_TYPE', u'RULE_OF_FIVE', u'FIRST_IN_CLASS', u'CHIRALITY', u'PRODRUG', u'ORAL', u'PARENTERAL', u'TOPICAL', u'BLACK_BOX', u'AVAILABILITY_TYPE', u'CANONICAL_SMILES'], dtype='object')

# %% [markdown]
# Quick look

# %%
dataframe[['DEVELOPMENT_PHASE', 'USAN_STEM', 'USAN_STEM_DEFINITION', 'USAN_STEM_SUBSTEM', 'INDICATION_CLASS', 'DRUG_TYPE']].head()
# Out:
#    DEVELOPMENT_PHASE USAN_STEM                     USAN_STEM_DEFINITION USAN_STEM_SUBSTEM            INDICATION_CLASS                 DRUG_TYPE
# 0                NaN     -orex                              anorexiants             -orex                    Anorexic  Synthetic Small Molecule
# 1                NaN    -mulin  antibacterials, pleuromulin derivatives            -mulin  Antibacterial (veterinary)  Synthetic Small Molecule
# 2                NaN       NaN                                      NaN               NaN              Antineoplastic  Synthetic Small Molecule
# 3                NaN  -fylline                 theophylline derivatives          -fylline                         NaN   Natural Product-derived
# 4                  4       NaN                                      NaN               NaN                         NaN   Natural Product-derived

# %% [markdown]
# ### Define [USAN stems](http://www.ama-assn.org/ama/pub/physician-resources/medical-science/united-states-adopted-names-council/naming-guidelines/approved-stems.page?) for kinase inhibitors

# %% [markdown]
# | STEM | what | example |
# | ------------- |-------------| -----|
# | -ciclib  | cyclin dependent kinase inhibitors (formerly -cidib)  | seliciclib |
# | -mapimod  | mitogen-activated protein (MAP) kinase inhibitors  | dormapimod |
# | -lisib  | phosphatidylinositol 3-kinase (PI3K) inhibitors  | pictilisib |
# | -rafenib  | rapidly accelerated fibrosarcoma (RAF) kinase  | inhibitors sorafenib |
# | -sertib  | serine/threonine kinase inhibitors  | danusertib |
# | -tinib  | tyrosine kinase inhibitors   | erlotinib |
# | -brutinib  | tyrosine kinase inhibitors Bruton's (Btk) inhibitors  | ibrutinib |
# | -citinib  | tyrosine kinase inhibitors; janus kinase inhibitors  | baricitinib |
# | -metinib  | tyrosine kinase inhibitors; MEK (MAP kinase) inhibitors  | binimetinib |
# | -rolimus | immunosuppressant, rapamycin derivatives | sirolimus |
# | -anib | angiogenesis inhibitors | Pazopanib |

# %%
def iskininh(x, y):
    """
    If stem found in string it returns true
    """
    stems = ["ciclib", "mapimod", "lisib", "rafenib", "sertib", "tinib", "brutinib", "citinib", "metinib", "rolimus", "anib"]
    for stem in stems:
        # check USAN_STEM
        if stem in str(x):
            return True
        # check USAN_STEM_SUBSTEM
        elif stem in str(y):
            return True
    return False

# %% [markdown]
# Tag rows with kinase inhibitors

# %%
dataframe['iskininh'] = dataframe.apply(lambda x: iskininh(x['USAN_STEM'],x['USAN_STEM_SUBSTEM']), axis=1)

# %% [markdown]
# Create a new data frame with only kinase inhibitors

# %%
nibs = dataframe[dataframe['iskininh'] == True]

# %%
len(nibs)
# Out:
# 113

# %%
nibs = nibs[nibs['CANONICAL_SMILES'].notnull()]

# %% [markdown]
# Add RDKit molecule objects to data frame

# %%
PandasTools.AddMoleculeColumnToFrame(nibs, smilesCol='CANONICAL_SMILES')

# %% [markdown]
# Remove oligonucleotides

# %%
nibs = nibs[nibs['DRUG_TYPE'] != 'Oligonucleotide']

# %% [markdown]
# Get only INN name

# %%
def innname(x):
    return x.split(' ')[0]

# %%
nibs['INN_NAME'] = nibs['SYNONYMS'].map(innname)

# %% [markdown]
# ### Show all kinase inhibitors

# %%
PandasTools.FrameToGridImage(nibs, legendsCol='INN_NAME', molsPerRow=7)
# Out:
# <PIL.Image.Image image mode=RGBA size=1400x3200 at 0x7F61AD905560>

# %% [markdown]
# ### Show only kinase inhibitors in phase 4 (drugs)

# %%
PandasTools.FrameToGridImage(nibs[nibs['DEVELOPMENT_PHASE'] == 4], legendsCol='INN_NAME', molsPerRow=4)
# Out:
# <PIL.Image.Image image mode=RGBA size=800x1400 at 0x7F61A93EE170>

# %% [markdown]
# #### List phase 4 kinase inhibitors

# %%
", ".join(sorted(list(nibs[nibs['DEVELOPMENT_PHASE'] == 4]['INN_NAME'])))
# Out:
# 'Afatinib, Axitinib, Bosutinib, Cabozantinib, Crizotinib, Dabrafenib, Dasatinib, Erlotinib, Everolimus, Gefitinib, Ibrutinib, Imatinib, Lapatinib, Nilotinib, Pazopanib, Pimecrolimus, Ponatinib, Regorafenib, Ruxolitinib, Sirolimus, Sorafenib, Sunitinib, Tacrolimus, Temsirolimus, Tofacitinib, Trametinib, Vandetanib, Vemurafenib'

# %% [markdown]
# ### How many kinase inhibitors and how many in phase 4

# %%
len(nibs), len(nibs[nibs['DEVELOPMENT_PHASE'] == 4])
# Out:
# (106, 28)

# %% [markdown]
# ##### Save SMILES

# %%
PandasTools.SaveSMILESFromFrame(nibs, 'kin_inh.smi', NamesCol='INN_NAME')

# %%
PandasTools.SaveSMILESFromFrame(nibs[nibs['DEVELOPMENT_PHASE'] == 4], 'kin_inh_approved.smi', NamesCol='INN_NAME')

# %% [markdown]
# #####Save csv

# %%
nibs.drop(['ROMol'], axis=1).to_csv('kin_inh.csv')

# %%
nibs.drop(['ROMol'], axis=1).tail(5)
# Out:
#        PARENT_MOLREGNO      CHEMBL_ID                                                    SYNONYMS  DEVELOPMENT_PHASE                 RESEARCH_CODES                                                   APPLICANTS USAN_STEM                                          USAN_STEM_DEFINITION USAN_STEM_SUBSTEM  USAN_YEAR  FIRST_APPROVAL          ATC_CODE                                                                                                                                                                                                                                               ATC_CODE_DESCRIPTION   INDICATION_CLASS                 DRUG_TYPE RULE_OF_FIVE FIRST_IN_CLASS            CHIRALITY PRODRUG ORAL PARENTERAL TOPICAL BLACK_BOX  AVAILABILITY_TYPE                                                                                                                                                                                      CANONICAL_SMILES iskininh     INN_NAME
# 9459            361444   CHEMBL217092      Saracatinib (INN, USAN); Saracatinib Difumarate (USAN)                NaN  AZD-0530; AZD-0530 difumarate                                                  Astrazeneca    -tinib                                    tyrosine kinase inhibitors            -tinib       2009             NaN               NaN                                                                                                                                                                                                                                                                NaN                NaN  Synthetic Small Molecule            N              N     Achiral Molecule       N  NaN        NaN     NaN       NaN                NaN                                                                                                                                           CN1CCN(CCOc2cc(OC3CCOCC3)c4c(Nc5c(Cl)ccc6OCOc56)ncnc4c2)CC1     True  Saracatinib
# 9766           1248731  CHEMBL1908360                                 Everolimus (FDA, INN, USAN)                  4                         RAD001  Novartis Pharmaceuticals Corp; Novartis Pharmaceutical Corp     -imus  immunosuppressives: immunosuppressant, rapamycin derivatives  -imus (-rolimus)       2003            2009  L01XE10; L04AA18          L01XE10 [Antineoplastic And Immunomodulating Agents:Antineoplastic Agents:Other Antineoplastic Agents:Protein kinase inhibitors]; L04AA18 [Antineoplastic And Immunomodulating Agents:Immunosuppressants:Immunosuppressants:Selective immunosuppressants]                NaN   Natural Product-derived            N              N  Single Stereoisomer       N    Y          N       N         Y  Prescription-only  CO[C@@H]1C[C@H](C[C@@H](C)[C@@H]2CC(=O)[C@H](C)\C=C(/C)\[C@@H](O)[C@@H](OC)C(=O)[C@H](C)C[C@H](C)\C=C\C=C\C=C(/C)\[C@H](C[C@@H]3CC[C@@H](C)[C@@](O)(O3)C(=O)C(=O)N4CCCC[C@H]4C(=O)O2)OC)CC[C@H]1OCCO     True   Everolimus
# 10208           602271   CHEMBL601719                                 Crizotinib (FDA, INN, USAN)                  4                     PF-2341066                                                   Pfizer Inc    -tinib                                    tyrosine kinase inhibitors            -tinib       2009            2011           L01XE16                                                                                                                                   L01XE16 [Antineoplastic And Immunomodulating Agents:Antineoplastic Agents:Other Antineoplastic Agents:Protein kinase inhibitors]                NaN  Synthetic Small Molecule            Y              Y  Single Stereoisomer       N    Y          N       N         N  Prescription-only                                                                                                                                               C[C@@H](Oc1cc(cnc1N)c2cnn(c2)C3CCNCC3)c4c(Cl)ccc(F)c4Cl     True   Crizotinib
# 10270            33576    CHEMBL24828                            Vandetanib (BAN, FDA, INN, USAN)                  4    GNF-Pf-2188; ZD-64; ZD-6474                                      Ipr Pharmaceuticals Inc     -anib                                       angiogenesis inhibitors             -anib       2006            2011           L01XE12                                                                                                                                   L01XE12 [Antineoplastic And Immunomodulating Agents:Antineoplastic Agents:Other Antineoplastic Agents:Protein kinase inhibitors]                NaN  Synthetic Small Molecule            N              N     Achiral Molecule       N    Y          N       N         Y  Prescription-only                                                                                                                                                         COc1cc2c(Nc3ccc(Br)cc3F)ncnc2cc1OCC4CCN(C)CC4     True   Vandetanib
# 10417              924   CHEMBL269732  Tacrolimus (FDA, BAN, INN, USAN); Tacrolimus Hydrate (JAN)                  4              FK-506; FR-900506                                       Astellas Pharma Us Inc     -imus  immunosuppressives: immunosuppressant, rapamycin derivatives  -imus (-rolimus)       1992            1994  L04AD02; D11AH01  L04AD02 [Antineoplastic And Immunomodulating Agents:Immunosuppressants:Immunosuppressants:Calcineurin inhibitors]; D11AH01 [Dermatologicals:Other Dermatological Preparations:Other Dermatological Preparations:Agents for dermatitis, excluding corticosteroids]  Immunosuppressant   Natural Product-derived            N              N  Single Stereoisomer       N    Y          Y       Y         Y  Prescription-only                                CO[C@@H]1C[C@@H](CC[C@H]1O)\C=C(/C)\[C@H]2OC(=O)[C@@H]3CCCCN3C(=O)C(=O)[C@]4(O)O[C@H]([C@H](C[C@@H](C)C\C(=C\[C@@H](CC=C)C(=O)C[C@H](O)[C@H]2C)\C)OC)[C@H](C[C@H]4C)OC     True   Tacrolimus

# %% [markdown]
# Copyright (C) 2013, 2014 by Samo Turk, BioMed X GmbH
#
# This work is licensed under the Creative Commons Attribution-ShareAlike 3.0 License. To view a copy of this license, visit http://creativecommons.org/licenses/by-sa/3.0/ or send a letter to Creative Commons, 543 Howard Street, 5th Floor, San Francisco, California, 94105, USA.
